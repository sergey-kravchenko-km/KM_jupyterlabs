# %% [markdown]
# <a href="https://colab.research.google.com/github/sergey-kravchenko-km/KM_jupyterlabs/blob/main/KM_LB7_Kravchenko.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа 7
# **Построение бинарного дерева поиска.
#  Подсчет количества элементов в дереве**
#  Кравченко Сергей 1 курс 5 группа

# %% [markdown]
# ## Задание 7.1 Определение классов

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-82098804-3680-47bb-887e-b99b862c2457" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82098804-3680-47bb-887e-b99b862c2457">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-45de06a9-e401-4dae-8b10-4ae02fe0ef10" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45de06a9-e401-4dae-8b10-4ae02fe0ef10">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e64ff0d4-c3c3-434d-9d64-c785aa0cc104" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e64ff0d4-c3c3-434d-9d64-c785aa0cc104">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
class BinaryTree:
    def __init__(self):
        self.root = EmptyNode()
    def __repr__(self):
        return repr(self.root)
    def insert(self, value):
        self.root = self.root.insert(value)

# %%
tree = BinaryTree()

# %%
class BinaryNode:
    def __init__(self, left, value, right):
        self.left = left
        self.value = value
        self.right = right

    def __repr__(self):
        return f'({self.left}, {self.value}, {self.right})'

    def insert(self, value):
        ...

# %%
node = BinaryNode(None, 5, None)
print(node)
# Out:
# (None, 5, None)

# %%
class EmptyNode:
    def __repr__(self):
        return '*'

    def insert(self, value):
        return BinaryNode(self, value, self)

# %%
tree = BinaryTree()

# %%
source_data = [5,1,10,3,4]

# %%
tree.insert(source_data[0])
tree
# Out:
# (*, 5, *)

# %% [markdown]
# ## Задание 7.2 Метод вставки элемента в бинарное дерево поиска

# %%
class BinaryNode:
    def __init__(self, left, value, right):
        self.left = left
        self.value = value
        self.right = right

    def __repr__(self):
        return f'({self.left}, {self.value}, {self.right})'

    def insert(self, value):
        if value < self.value:
            if isinstance(self.left, EmptyNode):
                self.left = BinaryNode(EmptyNode(), value, EmptyNode())
            else:
                self.left = self.left.insert(value)
        elif value > self.value:
            if isinstance(self.right, EmptyNode):
                self.right = BinaryNode(EmptyNode(), value, EmptyNode())
            else:
                self.right = self.right.insert(value)
        return self

# %%
tree.insert(source_data[1])
tree
# Out:
# None

# %%
tree.insert(source_data[2])
tree
# Out:
# (*, 4, (*, 10, *))

# %%
tree.insert(source_data[3])
tree
# Out:
# ((*, 3, *), 4, (*, 10, *))

# %%
tree.insert(source_data[4])
tree
# Out:
# (*, 4, *)

# %%
tree = BinaryTree()

# %%
tree = BinaryTree()
s = "ABCDE"
for i in s:
    tree.insert(i)
print(tree)
tree = BinaryTree()
s = "BACDE"
for i in s:
    tree.insert(i)
print(tree)
# Out:
# (*, A, (*, B, (*, C, (*, D, (*, E, *)))))
# ((*, A, *), B, (*, C, (*, D, (*, E, *))))

# %%
tree = BinaryTree()
s = 'computer mathematics'
for i in s:
    tree.insert(i)
print(tree)
# Out:
# ((*,  , (*, a, *)), c, (((*, e, (*, h, (*, i, *))), m, *), o, (*, p, (((*, r, (*, s, *)), t, *), u, *))))

# %%
tree = BinaryTree()

for i in range(5):
    tree.insert(i)
print(tree)
# Out:
# (*, 0, (*, 1, (*, 2, (*, 3, (*, 4, *)))))

# %%
tree = BinaryTree()
l = [1,6,2,9,19,12,5]
for i in l:
    tree.insert(i)
print(tree)
# Out:
# (*, 1, ((*, 2, (*, 5, *)), 6, (*, 9, ((*, 12, *), 19, *))))

# %% [markdown]
# ## Задание 7.3 Построение бинарного дерева поиска

# %% [markdown]
# ### 1. Столбец чисел

# %%
with open('столбец.txt', 'r', encoding= 'utf8') as f:
    file1 = BinaryTree()

    for i in f.readlines():
        file1.insert(int(i.strip()))

# %%
file1
# Out:
# ((*, 1, (*, 2, (*, 3, *))), 4, ((*, 10, *), 12, (((*, 39, *), 45, *), 54, (*, 78, *))))

# %% [markdown]
# ### 2. Строки чисел

# %%
with open('строки.txt', 'r', encoding='utf8') as f:
    a = []
    for i in f.readlines():
        a.extend(i.strip().split())
file2 = BinaryTree()
for i in a:
    file2.insert((int(i.strip())))
file2
# Out:
# (((*, 1, *), 2, (*, 3, (*, 4, (*, 5, (*, 6, *))))), 7, (((*, 11, *), 12, ((*, 13, *), 36, ((*, 43, (*, 56, *)), 76, (*, 231, *)))), 817, (*, 918, *)))

# %% [markdown]
# ### 3. С использование numpy

# %%
import numpy as np



data = np.loadtxt('столбец.txt', dtype=int)

file3 = BinaryTree()
for value in data:
    file3.insert(value)

print(file3)
# Out:
# ((*, 1, (*, 2, (*, 3, *))), 4, ((*, 10, *), 12, (((*, 39, *), 45, *), 54, (*, 78, *))))

# %% [markdown]
# ### 4. JSON файл

# %%
import json


# Чтение данных из JSON файла
with open('строки.json', 'r', encoding='utf8') as f:
    data = json.load(f)

file4 = BinaryTree()

# Если data - список чисел
if isinstance(data, list):
    for i in data:
        file4.insert(int(i))
# Если data - строка с числами через пробел
elif isinstance(data, str):
    numbers = data.split()
    for i in numbers:
        file4.insert(int(i))
# Если data - одно число
else:
    file4.insert(int(data))
file4
# Out:
# (*, 10, (*, 20, (*, 30, (*, 40, (*, 50, (*, 60, (*, 70, *)))))))

# %% [markdown]
# ## Задание 7.4 Перегрузка операции принадлежности in

# %%
class BinaryTree:
    def __init__(self):
        self.root = EmptyNode()

    def __repr__(self):
        return repr(self.root)

    def insert(self, value):
        self.root = self.root.insert(value)

    def __contains__(self, value):

        return value in self.root


class EmptyNode:
    def __repr__(self):
        return '*'

    def insert(self, value):
        return BinaryNode(self, value, self)

    def __contains__(self, value):
        #Пустой узел не содержит никаких значений
        return False


class BinaryNode:
    def __init__(self, left, value, right):
        self.left = left
        self.value = value
        self.right = right

    def __repr__(self):
        return f'({self.left}, {self.value}, {self.right})'

    def insert(self, value):
        if value < self.value:
            if isinstance(self.left, EmptyNode):
                self.left = BinaryNode(EmptyNode(), value, EmptyNode())
            else:
                self.left = self.left.insert(value)
        elif value > self.value:
            if isinstance(self.right, EmptyNode):
                self.right = BinaryNode(EmptyNode(), value, EmptyNode())
            else:
                self.right = self.right.insert(value)
        return self

    def __contains__(self, value):

        if value == self.value:
            return True
        elif value < self.value:
            return value in self.left
        else:
            return value in self.right

# %%
tree = BinaryTree()
tree.insert(50)
tree.insert(30)
tree.insert(70)
tree.insert(20)
tree.insert(40)
tree.insert(60)
tree.insert(80)


print(50 in tree)
print(30 in tree)
print(67 in tree)
print(20 in tree)
# Out:
# True
# True
# False
# True

# %%
source_data = [5,1,10,3,4]
tree = BinaryTree()
for i in source_data:
 tree.insert(i)
 print(tree)
for i in range(11):
 print((i, i in tree), end = ' ')
# Out:
# (*, 5, *)
# ((*, 1, *), 5, *)
# ((*, 1, *), 5, (*, 10, *))
# ((*, 1, (*, 3, *)), 5, (*, 10, *))
# ((*, 1, (*, 3, (*, 4, *))), 5, (*, 10, *))
# (0, False) (1, True) (2, False) (3, True) (4, True) (5, True) (6, False) (7, False) (8, False) (9, False) (10, True)

# %% [markdown]
# ## Задание 7.5 Перегрузка встроенной функции len

# %%
class BinaryTree:
    def __init__(self):
        self.root = EmptyNode()

    def __repr__(self):
        return repr(self.root)

    def insert(self, value):
        self.root = self.root.insert(value)

    def __contains__(self, value):

        return value in self.root
    def __len__(self):
        return len(self.root)

class EmptyNode:
    def __repr__(self):
        return '*'

    def insert(self, value):
        return BinaryNode(self, value, self)

    def __contains__(self, value):

        return False

    def __len__(self):
        return 0

class BinaryNode:
    def __init__(self, left, value, right):
        self.left = left
        self.value = value
        self.right = right

    def __repr__(self):
        return f'({self.left}, {self.value}, {self.right})'

    def insert(self, value):
        if value < self.value:
            if isinstance(self.left, EmptyNode):
                self.left = BinaryNode(EmptyNode(), value, EmptyNode())
            else:
                self.left = self.left.insert(value)
        elif value > self.value:
            if isinstance(self.right, EmptyNode):
                self.right = BinaryNode(EmptyNode(), value, EmptyNode())
            else:
                self.right = self.right.insert(value)
        return self

    def __contains__(self, value):

        if value == self.value:
            return True
        elif value < self.value:
            return value in self.left
        else:
            return value in self.right
    def __len__(self):
        return 1 + len(self.left) + len(self.right)

# %%
tree = BinaryTree()
for i in source_data:
 tree.insert(i)
len(tree)
# Out:
# 5

# %%
emptree = BinaryTree()
print(len(emptree))
emptree.insert(1)
print(len(emptree))
# Out:
# 0
# 1

# %% [markdown]
# ## Задание 7.6 Трассировка объектного уровня

# %% [markdown]
# ***
#
# ### Задание 1. Вставка новой вершины в непустое бинарное дерево (вставка значения 1 в дерево с корнем 5)
#
# **Вызов:** `tree.insert(1)`
#
# 1. `tree.insert(1)` вызывает метод `insert` класса `BinaryTree`
#
# 2. Внутри него происходит:
#    `self.root = self.root.insert(1)`
#
# 3. На момент вызова `self.root` ссылается на объект типа `BinaryNode` со значением `5`
#
# 4. Вызывается метод `insert` класса `BinaryNode` с аргументом `1`
#
# 5. В методе `insert` класса `BinaryNode`:
#    - Сравниваем `1` и текущее значение `5`
#    - Так как `1 < 5`, переходим к левому поддереву
#    - Проверяем тип левого потомка (`self.left`). В данный момент `self.left` — это объект типа `EmptyNode` (пустой узел)
#
# 6. Условие `isinstance(self.left, EmptyNode)` истинно, поэтому создаётся новый узел:
#    `self.left = BinaryNode(EmptyNode(), 1, EmptyNode())`
#
# 7. Левый потомок текущего узла теперь ссылается на новый объект `BinaryNode` со значением `1` и двумя пустыми поддеревьями
#
# 8. Метод возвращает текущий узел (`self`), который остаётся корнем дерева
#
# 9. В методе `BinaryTree.insert` ссылка `self.root` обновляется (хотя фактически остаётся тем же объектом)
#
# ***
#
# **Схема объектов после вставки:**
#
# ```
# tree (BinaryTree)
#   │
#   └─ root → BinaryNode (value = 5)
#               │
#               ├─ left → BinaryNode (value = 1)
#               │          │
#               │          ├─ left → EmptyNode
#               │          │
#               │          └─ right → EmptyNode
#               │
#               └─ right → EmptyNode
# ```
#
# ***
#
# ### Задание 2. Создание «пустого» дерева
#
# **Вызов:** `tree = BinaryTree()`
#
# 1. Создаётся новый экземпляр класса `BinaryTree`
#
# 2. Вызывается метод `__init__` класса `BinaryTree`, который выполняет:
#    `self.root = EmptyNode()`
#
# 3. `EmptyNode()` создаёт новый экземпляр класса `EmptyNode` — объект, представляющий "пустую" вершину
#
# 4. Ссылка `root` внутри объекта `tree` устанавливается на этот пустой узел
#
# ***
#
# **Схема объектов после создания:**
#
# ```
# tree (BinaryTree)
#   │
#   └─ root → EmptyNode
# ```
#
# ***
#
# **Свойства пустого дерева:**
#
# ***
#
# | Свойство | Описание |
# |----------|----------|
# | ✓ | Не содержит ни одного числового значения |
# | ✓ | Любая операция вставки начнётся с вызова метода `insert` у объекта `EmptyNode`, который создаст полноценный узел `BinaryNode` |
# | ✓ | Функция `len(tree)` вернёт `0`, так как `EmptyNode.__len__` возвращает `0` |
# | ✓ | Проверка `value in tree` всегда будет `False`, так как `EmptyNode.__contains__` возвращает `False` |
#
# ***
#
# ### Задание 3. Трассировка объектного уровня для `tree.insert(source_data[2])`
#
# **Исходные данные:** `source_data = [5, 1, 10, 3, 4]`
#
# **Текущее дерево после вставки 5 и 1:**
#
# ```
#         5
#        /
#       1
# ```
#
# **Вставка следующей вершины:** `tree.insert(10)` (третий элемент, индекс 2)
#
# ***
#
# **Пошаговая трассировка**
#
# ***
#
# **Шаг 1.** Вызов метода `tree.insert(10)` класса `BinaryTree`
#
# **Шаг 2.** Вычисление `self.root.insert(10)`:
#    - `self.root` ссылается на корневой узел со значением `5` (тип `BinaryNode`)
#
# **Шаг 3.** Вход в метод `insert` класса `BinaryNode` для узла `5`:
#
#    ```
#    def insert(self, value):
#        if value < self.value:
#            # 10 < 5? → False
#        elif value > self.value:
#            # 10 > 5 → True
#            if isinstance(self.right, EmptyNode):
#                self.right = BinaryNode(EmptyNode(), value, EmptyNode())
#            else:
#                self.right = self.right.insert(value)
#    ```
#
# **Шаг 4.** Проверка правого потомка узла `5`:
#    - `self.right` в данный момент — `EmptyNode` (правое поддерево пусто)
#    - Условие `isinstance(self.right, EmptyNode)` истинно
#
# **Шаг 5.** Создание нового узла для значения `10`:
#    `self.right = BinaryNode(EmptyNode(), 10, EmptyNode())`
#
# **Шаг 6.** Новый узел инициализируется:
#    - `left` = `EmptyNode()`
#    - `value` = `10`
#    - `right` = `EmptyNode()`
#
# **Шаг 7.** Метод возвращает текущий узел (`self` — узел `5`), который остаётся корнем
#
# **Шаг 8.** В методе `BinaryTree.insert` ссылка `self.root` сохраняется на тот же узел `5`
#
# ***
#
# **Итоговая схема объектов после вставки 10**
#
# ```
# tree (BinaryTree)
#   │
#   └─ root → BinaryNode (value = 5)
#               │
#               ├─ left → BinaryNode (value = 1)
#               │         │
#               │         ├─ left → EmptyNode
#               │         │
#               │         └─ right → EmptyNode
#               │
#               └─ right → BinaryNode (value = 10)
#                         │
#                         ├─ left → EmptyNode
#                         │
#                         └─ right → EmptyNode
# ```
#
# ***
#
# **Состояние памяти (объектный уровень)**
#
# ***
#
# | Объект | Тип | Атрибуты |
# |--------|-----|----------|
# | tree | BinaryTree | root → ссылка на BinaryNode(5) |
# | node_5 | BinaryNode | left → BinaryNode(1), value = 5, right → BinaryNode(10) |
# | node_1 | BinaryNode | left → EmptyNode, value = 1, right → EmptyNode |
# | node_10 | BinaryNode | left → EmptyNode, value = 10, right → EmptyNode |
# | empty1 | EmptyNode | (нет атрибутов) |
# | empty2 | EmptyNode | (нет атрибутов) |
# | empty3 | EmptyNode | (нет атрибутов) |
#
# ***
#
# **Результат выполнения**
#
# После вставки дерево содержит три вершины: `5`, `1`, `10`. Дерево удовлетворяет свойству бинарного поиска: все значения в левом поддереве `5` меньше `5`, все значения в правом поддереве больше `5`.
#
# ***
